# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename = "logs/ingestion_db.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(lavelname)s - %(message)s",
    filemode = "a"
)


engine = create_engine('sqlite:///inventory.db')

def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists = 'replace', index = False)

def load_raw_data():
    '''This function will load the CSV as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir('data'):
        if '.csv' in file:
            df = pd.read_csv('data/'+file)
            logging.info(f'Ingesting{file} in db')
            ingest_db(df, file[:-4], engine)
        end = time.time()
        total_time = (end - start)/60
        logging.info('----------Ingestion Complete----------')
        logging.info(f'Total Time Taken: {total_time} minutes')

if __name__ == '__main__':
    load_raw_data()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 27, in load_raw_data
#     logging.info(f'Ingesting{file} in db')
# Message: 'Ingestingbegin_inventory.csv in db'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 31, in load_raw_data
#     logging.info('----------Ingestion Complete----------')
# Message: '----------Ingestion Complete----------'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 32, in load_raw_data
#     logging.info(f'Total Time Taken: {total_time} minutes')
# Message: 'Total Time Taken: 0.06811978816986083 minutes'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 27, in load_raw_data
#     logging.info(f'Ingesting{file} in db')
# Message: 'Ingestingend_inventory.csv in db'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 31, in load_raw_data
#     logging.info('----------Ingestion Complete----------')
# Message: '----------Ingestion Complete----------'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 32, in load_raw_data
#     logging.info(f'Total Time Taken: {total_time} minutes')
# Message: 'Total Time Taken: 0.1414247711499532 minutes'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 27, in load_raw_data
#     logging.info(f'Ingesting{file} in db')
# Message: 'Ingestingpurchases.csv in db'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 31, in load_raw_data
#     logging.info('----------Ingestion Complete----------')
# Message: '----------Ingestion Complete----------'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 32, in load_raw_data
#     logging.info(f'Total Time Taken: {total_time} minutes')
# Message: 'Total Time Taken: 1.4252122322718301 minutes'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 27, in load_raw_data
#     logging.info(f'Ingesting{file} in db')
# Message: 'Ingestingpurchase_prices.csv in db'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
# ...
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 32, in load_raw_data
#     logging.info(f'Total Time Taken: {total_time} minutes')
# Message: 'Total Time Taken: 24.245959142843883 minutes'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 27, in load_raw_data
#     logging.info(f'Ingesting{file} in db')
# Message: 'Ingestingvendor_invoice.csv in db'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 31, in load_raw_data
#     logging.info('----------Ingestion Complete----------')
# Message: '----------Ingestion Complete----------'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\nafiz\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'lavelname'
# Call stack:
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\nafiz\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#     handle._run()
#   File "C:\Users\nafiz\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\nafiz\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 35, in <module>
#     load_raw_data()
#   File "C:\Users\nafiz\AppData\Local\Temp\ipykernel_5100\695654481.py", line 32, in load_raw_data
#     logging.info(f'Total Time Taken: {total_time} minutes')
# Message: 'Total Time Taken: 24.286271182696023 minutes'
# Arguments: ()
